# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd

# %%
titanic['age']=titanic['age'].fillna('o')

# %%
titanic['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888       o
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: object

# %% [markdown]
# # Exercises
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot! **

# %%
sns.jointplot(data=titanic , x='fare' , y='age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "o"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sns.jointplot(data=titanic , x='fare' , y='age')
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2257, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2254 if kind.startswith("scatter"):
#    2256     joint_kws.setdefault("color", color)
# -> 2257     grid.plot_joint(scatterplot, **joint_kws)
#    2259     if grid.hue is None:
#    2260         marg_func = histplot
#
# ...

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male     o      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
titanic['age']=titanic['age'].replace('o','0')

# %%
titanic['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888       0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: object

# %%
plt.show(sns.jointplot(data=titanic , x='fare' , y='age'))

# %%
plt.show(sns.displot(titanic['fare']))

# %%
plt.show(sns.boxplot(data=titanic , x="class" , y="age"))

# %%
plt.show(sns.swarmplot(x='class', y='age',data=titanic, palette='Set1',size=3))
# Out:
# C:\Users\jayde\AppData\Local\Temp\ipykernel_33832\2508821551.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plt.show(sns.swarmplot(x='class', y='age',data=titanic, palette='Set1',size=3))
# C:\Users\jayde\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\jayde\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 22.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.show(sns.countplot(data=titanic , x="sex"))

# %%
titanic.corr(numeric_only=True)
# Out:
#             survived    pclass     sibsp     parch      fare  adult_male  \
# survived    1.000000 -0.338481 -0.035322  0.081629  0.257307   -0.557080
# pclass     -0.338481  1.000000  0.083081  0.018443 -0.549500    0.094035
# sibsp      -0.035322  0.083081  1.000000  0.414838  0.159651   -0.253586
# parch       0.081629  0.018443  0.414838  1.000000  0.216225   -0.349943
# fare        0.257307 -0.549500  0.159651  0.216225  1.000000   -0.182024
# adult_male -0.557080  0.094035 -0.253586 -0.349943 -0.182024    1.000000
# alone      -0.203367  0.135207 -0.584471 -0.583398 -0.271832    0.404744
#
#                alone
# survived   -0.203367
# pclass      0.135207
# sibsp      -0.584471
# parch      -0.583398
# fare       -0.271832
# adult_male  0.404744
# alone       1.000000

# %%
plt.show(sns.heatmap(titanic.corr(numeric_only=True),cmap='crest'))

# %%
titanic=titanic.dropna(subset=['age'])

# %%
titanic['age']=pd.to_numeric(titanic['age'])

# %%
titanic=titanic[titanic['age']>0]

# %%
jay=sns.FacetGrid(data=titanic,col='sex',height=5)
jay.map(sns.histplot, "age",bins=20,kde=False)
plt.show()
